# %%
import pyautogui
import time
import pyperclip
import pandas

# %%
pyautogui.PAUSE = 3
pyautogui.click(x=498, y=879)
pyautogui.hotkey ("c", "h", "r", "o", "m", "e")
pyautogui.hotkey ("enter")
pyautogui.click(x=529, y=489)
pyautogui.hotkey ("ctrl", "t")
pyautogui.click(x=1236, y=117)
pyautogui.click(x=37, y=246)
pyautogui.click(x=554, y=117)
pyautogui.hotkey ("f", "e", "l", "i", "p", "e", " ", "m", "a", "r", "i", "n", "h", "o", " ", "d", "e", " ", "a", "n", "d", "r", "a", "d", "e", " ")
pyautogui.click(x=622, y=181)
pyautogui.hotkey ("s", "e", "u", " ", "b", "o", "s", "t", "a")
pyautogui.hotkey ("enter")

# %%
time.sleep(3)
pyautogui.position()
# Out:
# Point(x=622, y=181)
