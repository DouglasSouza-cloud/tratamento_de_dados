# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 2
pyautogui.hotkey("ctrl","t")
pyperclip.copy("https://drive.google.com/drive/folders/1PDmvU5FNWNNxG7K_xrBajnlvto_iYayI?usp=drive_link")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")

# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 2

pyautogui.hotkey("ctrl", "t")

pyperclip.copy("https://docs.google.com/spreadsheets/d/1GMYNSaTNpI9EKlWXIhnIeqssWvlB4F5I/edit?usp=sharing&ouid=112654896503130342889&rtpof=true&sd=true")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

pyautogui.click(x=71, y=117)
pyautogui.click(x=158, y=398)
pyautogui.click(x=437, y=405)

time.sleep(3)

# %%
import pyautogui
import time

time.sleep(5)

pyautogui.position()
# Out:
# Point(x=122, y=399)
